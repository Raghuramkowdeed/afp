# %%
import numpy as np
import pandas as pd
import os as os
import time

# %%
os.chdir('../')

# %%
# %pylab inline
exec(open("./run_model.py").read())
exec(open("./get_signal_names.py").read())
exec(open("./portfolio_optimizer.py").read())

import datetime
from pylab import rcParams
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sig_type = 'rank'
#rank
#norm
size_tag = '500_3000'
#0_3000
#0_500
#500_3000
#use_pickle = True 


    

sig_dir =      '../afp_data/' + sig_type + '/' +  size_tag + '/rps_data/'
fac_data_dir=  '../afp_data/' + sig_type + '/' +  size_tag + '/factor_exposure_data/'
fac_ret_file = '../afp_data/' + sig_type + '/' +  size_tag + '/fac_ret_file.csv'

# %%
use_pickle = True 

if use_pickle :
    file_name = '../afp_pickle/'+'sig_'+sig_type +'_'+size_tag +'.pkl' 
    sig_df = pd.read_pickle(file_name)
    #sig_df = pd.read_pickle('../afp_pickle/_rank_0_500.pkl')
else :
    sig_df = pd.DataFrame()
    sig_files = os.listdir(sig_dir)
    sig_files = np.sort(sig_files)



    for sig_file in sig_files :
        if '.csv' not in sig_file :
            continue
        print(sig_file)
        this_file = sig_dir + sig_file
        this_df = pd.read_csv(this_file, index_col = 'date')
        this_df.index = [ datetime.datetime.strptime(val, '%Y-%m-%d') for val in this_df.index]
        #this_df = this_df.sort_values(['mve'], ascending=False)
        #this_df = this_df.iloc[start_stock_ind:end_stock_ind,:]
        sig_df = sig_df.append(this_df)
    #data = sig_df.copy()

# %%
#model_name = 'linear_regression'
#train_model_arg = { 'fit_intercept':True }

model_name = 'knn'
train_model_arg = None

# %%
begin_date = datetime.datetime.strptime('19900101', '%Y%m%d')
end_date = datetime.datetime.strptime('20170101', '%Y%m%d')

sig_df = sig_df[(sig_df.index>=begin_date) & (sig_df.index<end_date)]
sig_df = sig_df.fillna(sig_df.mean())

# %%
'res_ret' in sig_df.columns
# Out:
# True

# %%
#factor_names =  ['beta','mve', 'bm', 'roic', 'agr', 'mom12m', 'idiovol']
factor_names =  ['beta']
sig_names = get_signal_names()
ret_sr = sig_df['ret']
sig_df = sig_df[sig_names]
sig_df = sig_df.drop(factor_names, axis=1)
sig_df = sig_df.drop(['idiovol'], axis=1)

# %%
pm = PortfolioOptimizer(fac_data_dir=fac_data_dir,
                        fac_ret_file = fac_ret_file,
                        fac_cov_hl = 12.0,
                        fac_names = None
                       )
# Out:
# --------

# %%
look_back = 1

knn_sig_df = pd.DataFrame()
lm_sig_df = pd.DataFrame()
kernel_sig_df = pd.DataFrame()

pnl_df = pd.DataFrame()
lm_pnl_df = pd.DataFrame()
knn_pnl_df = pd.DataFrame()
#kernel_pnl_df = pd.DataFrame()

shrp_df = pd.DataFrame()

#these_signals = ['mve', 'bm', 'roic', 'agr', 'mom12m',]
these_signals = sig_df.columns

for sig_name in these_signals :
    print(sig_name)
    
    try :
        t0 = time.time()
        
        this_sig_sr = sig_df[ [sig_name] ].copy()
        #unmodified signal
        pnl_sr = pm.run_signal(this_sig_sr.iloc[:,0], neu_sig=True)
        pnl_df[sig_name] = pnl_sr
        
        #linear signal
        print('lm')
        lm_sig_sr,mvc = run_model( this_sig_sr, ret_sr, model_name='linear_regression', train_model_arg=train_model_arg, 
                          pred_model_arg ={},look_back=look_back, sample_decay = 0.0)
        lm_sig_df[sig_name] = lm_sig_sr
        lm_pnl_sr = pm.run_signal(lm_sig_sr, neu_sig=True)
        lm_pnl_df[sig_name] = lm_pnl_sr
        
        #knn signal
        print('knn')
        knn_sig_sr,mvc = run_model( this_sig_sr, ret_sr, model_name='knn', train_model_arg=train_model_arg, 
                          pred_model_arg ={},look_back=look_back, sample_decay = 0.0)
        knn_sig_df[sig_name] = knn_sig_sr   
        knn_pnl_sr = pm.run_signal(knn_sig_sr, neu_sig=True)
        knn_pnl_df[sig_name] = knn_pnl_sr
        
        #kernel signal
        #print('kernel')
        #kernel_sig_sr,mvc = run_model( this_sig_sr, ret_sr, model_name='ridge_kernel', train_model_arg=train_model_arg, 
        #                  pred_model_arg ={},look_back=look_back, sample_decay = 0.5)
        #kernel_sig_df[sig_name] = kernel_sig_sr   
        #kernel_pnl_sr = pm.run_signal(kernel_sig_sr, neu_sig=True)
        #kernel_pnl_df[sig_name] = kernel_pnl_sr
        
        
        s1 = pnl_sr.mean()*sqrt(12)/ pnl_sr.std()
        s2 = lm_pnl_sr.mean()*sqrt(12)/ lm_pnl_sr.std()
        s3 = knn_pnl_sr.mean()*sqrt(12)/ knn_pnl_sr.std()
        #s4  = kernel_pnl_sr.mean()*sqrt(12)/ kernel_pnl_sr.std()
        
        #this_shrp = pd.Series([s1,s2,s3,s4], index=['org', 'lm', 'knn', 'kernel'], name = sig_name)
        this_shrp = pd.Series([s1,s2,s3], index=['org', 'lm', 'knn',], name = sig_name)
        shrp_df = shrp_df.append(this_shrp)
        
        t1 = time.time()
        this_time = t1-t0
        print('time = ' + str(this_time)) 
        print(this_shrp)
        
    except Exception as e :
        print(e)
# Out:
# absacc
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 70.58668494224548
# org   -0.256707
# lm     0.248757
# knn    0.342400
# Name: absacc, dtype: float64
# acc
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 66.16536593437195
# org   -0.178190
# lm     0.258891
# knn    0.467904
# Name: acc, dtype: float64
# aeavol
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.52542185783386
# org   -0.181104
# lm    -0.022908
# knn   -0.073287
# Name: aeavol, dtype: float64
# age
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 68.83527302742004
# org    0.790088
# lm     0.284635
# knn    0.304606
# Name: age, dtype: float64
# agr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 63.713977098464966
# org   -0.846595
# lm     0.361842
# knn    0.341604
# Name: agr, dtype: float64
# baspread
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 62.441100120544434
# org   -1.399495
# lm     0.152876
# knn    0.240572
# Name: baspread, dtype: float64
# betasq
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.89179801940918
# org   -1.226691
# lm     0.029149
# knn   -0.037806
# Name: betasq, dtype: float64
# bm
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 62.283401012420654
# org    0.827803
# lm     0.497993
# knn    0.727695
# Name: bm, dtype: float64
# bm_ia
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 62.080769062042236
# org   -0.021122
# lm     0.399540
# knn    0.850906
# Name: bm_ia, dtype: float64
# cash
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 63.39193511009216
# org   -0.238726
# lm     0.411217
# knn    0.548382
# Name: cash, dtype: float64
# cashdebt
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.630616903305054
# org    0.095231
# lm     0.293851
# knn    0.729447
# Name: cashdebt, dtype: float64
# cashpr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 60.623029947280884
# org   -0.802783
# lm     0.411995
# knn    0.607867
# Name: cashpr, dtype: float64
# cfp
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.46651482582092
# org    1.170750
# lm     0.537865
# knn    0.832312
# Name: cfp, dtype: float64
# cfp_ia
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.538182973861694
# org    0.698355
# lm     0.567585
# knn    0.954801
# Name: cfp_ia, dtype: float64
# chatoia
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 62.786895990371704
# org    0.511481
# lm     0.312915
# knn    0.480565
# Name: chatoia, dtype: float64
# chcsho
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 62.57671284675598
# org   -1.022760
# lm     0.344483
# knn    0.394903
# Name: chcsho, dtype: float64
# chempia
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 76.25576400756836
# org   -0.110392
# lm     0.352482
# knn    0.413800
# Name: chempia, dtype: float64
# chfeps
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 81.47664093971252
# org    0.942321
# lm     0.771585
# knn    0.582222
# Name: chfeps, dtype: float64
# chinv
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 68.68945407867432
# org   -0.821592
# lm     0.675651
# knn    0.616154
# Name: chinv, dtype: float64
# chmom
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.9224750995636
# org   -0.633903
# lm     0.229185
# knn    0.254937
# Name: chmom, dtype: float64
# chnanalyst
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 75.10130596160889
# org    0.137409
# lm     0.091925
# knn    0.131322
# Name: chnanalyst, dtype: float64
# chpmia
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 60.60388994216919
# org    0.258342
# lm    -0.049767
# knn    0.656452
# Name: chpmia, dtype: float64
# chtx
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.286603927612305
# org    0.348074
# lm     0.188957
# knn    0.412360
# Name: chtx, dtype: float64
# cinvest
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 60.30580401420593
# org   -0.176943
# lm    -0.162151
# knn    0.532964
# Name: cinvest, dtype: float64
# convind
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 82.6038339138031
# org   -0.583662
# lm     0.307155
# knn    0.041899
# Name: convind, dtype: float64
# currat
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 60.29276204109192
# org   -0.695051
# lm     0.364762
# knn    0.769328
# Name: currat, dtype: float64
# depr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 61.20666313171387
# org   -0.153030
# lm     0.336846
# knn    0.615026
# Name: depr, dtype: float64
# disp
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 66.24402594566345
# org   -0.852783
# lm     0.496606
# knn    0.632445
# Name: disp, dtype: float64
# divi
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 84.26956796646118
# org   -0.801413
# lm     0.101408
# knn    0.147040
# Name: divi, dtype: float64
# orgcap
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 76.41298198699951
# org   -0.158529
# lm     0.259155
# knn    0.820155
# Name: orgcap, dtype: float64
# pchcapx_ia
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 65.73540592193604
# org   -0.137307
# lm     0.197935
# knn    0.621600
# Name: pchcapx_ia, dtype: float64
# pchcurrat
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 65.97119903564453
# org   -0.175637
# lm     0.344752
# knn    0.472967
# Name: pchcurrat, dtype: float64
# pchdepr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 66.35105204582214
# org    0.223031
# lm     0.163066
# knn    0.313542
# Name: pchdepr, dtype: float64
# pchgm_pchsale
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.63210606575012
# org    0.773244
# lm     0.505493
# knn    0.543007
# Name: pchgm_pchsale, dtype: float64
# pchquick
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 72.26914191246033
# org   -0.105885
# lm     0.540401
# knn    0.508636
# Name: pchquick, dtype: float64
# pchsale_pchinvt
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 87.87753105163574
# org    0.673044
# lm     0.170690
# knn    0.245723
# Name: pchsale_pchinvt, dtype: float64
# pchsale_pchxsga
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 83.59076404571533
# org   -0.355972
# lm     0.005165
# knn    0.584479
# Name: pchsale_pchxsga, dtype: float64
# pchsaleinv
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 78.60449004173279
# org   -0.038730
# lm     0.112858
# knn    0.305947
# Name: pchsaleinv, dtype: float64
# pctacc
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 68.02041602134705
# org   -0.878977
# lm     0.383164
# knn    0.630848
# Name: pctacc, dtype: float64
# pricedelay
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 66.43334817886353
# org   -0.453041
# lm     0.246062
# knn    0.351870
# Name: pricedelay, dtype: float64
# ps
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 82.67591404914856
# org    0.577379
# lm     0.410976
# knn    0.652409
# Name: ps, dtype: float64
# divo
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 88.47247791290283
# org   -0.954541
# lm     0.487123
# knn    0.369530
# Name: divo, dtype: float64
# dolvol
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 63.001595973968506
# org    0.417527
# lm    -0.157222
# knn   -0.481703
# Name: dolvol, dtype: float64
# dy
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 75.12472605705261
# org    0.931669
# lm     0.229980
# knn    0.396852
# Name: dy, dtype: float64
# ear
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 62.9135160446167
# org    0.922876
# lm     0.191142
# knn    0.127750
# Name: ear, dtype: float64
# egr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 63.798880100250244
# org   -0.747096
# lm     0.468664
# knn    0.527231
# Name: egr, dtype: float64
# ep
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 65.17930316925049
# org    1.135397
# lm     0.261861
# knn    0.657776
# Name: ep, dtype: float64
# fgr5yr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 74.60190296173096
# org   -0.647377
# lm     0.279517
# knn    0.455260
# Name: fgr5yr, dtype: float64
# gma
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.50286889076233
# org   -0.446505
# lm     0.334565
# knn    0.773292
# Name: gma, dtype: float64
# grcapx
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 66.47147178649902
# org   -1.132122
# lm     0.435187
# knn    0.768587
# Name: grcapx, dtype: float64
# grltnoa
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 76.39760518074036
# org   -0.676446
# lm     0.140843
# knn    0.515928
# Name: grltnoa, dtype: float64
# herf
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 79.48043513298035
# org   -0.857377
# lm     0.410759
# knn    0.883642
# Name: herf, dtype: float64
# hire
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 71.40087485313416
# org   -0.895839
# lm     0.492817
# knn    0.561049
# Name: hire, dtype: float64
# ill
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 69.38485908508301
# org   -0.752789
# lm    -0.117265
# knn   -0.327662
# Name: ill, dtype: float64
# indmom
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 74.47567200660706
# org    0.901966
# lm     0.390579
# knn    0.451213
# Name: indmom, dtype: float64
# invest
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 73.35179495811462
# org   -0.871180
# lm     0.375167
# knn    0.738462
# Name: invest, dtype: float64
# ipo
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 89.65194416046143
# org   -0.711213
# lm     0.127180
# knn    0.187195
# Name: ipo, dtype: float64
# lev
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.5345630645752
# org    0.789335
# lm     0.520337
# knn    0.849960
# Name: lev, dtype: float64
# lgr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.79252004623413
# org   -0.744540
# lm     0.052049
# knn    0.443294
# Name: lgr, dtype: float64
# maxret
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 63.33729910850525
# org   -1.678391
# lm     0.395977
# knn    0.465677
# Name: maxret, dtype: float64
# mom12m
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.6979968547821
# org    0.559774
# lm     0.466603
# knn    0.628038
# Name: mom12m, dtype: float64
# mom1m
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 74.09321117401123
# org   -0.959855
# lm     0.176484
# knn    0.275501
# Name: mom1m, dtype: float64
# mom36m
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 73.3427848815918
# org    0.128060
# lm     0.353565
# knn    0.424241
# Name: mom36m, dtype: float64
# mom6m
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 65.20031380653381
# org    0.341195
# lm     0.305274
# knn    0.474393
# Name: mom6m, dtype: float64
# ms
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 77.79805302619934
# org    0.899947
# lm     0.735296
# knn    0.890541
# Name: ms, dtype: float64
# mve
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 65.85036087036133
# org    0.680907
# lm     0.128078
# knn   -0.197335
# Name: mve, dtype: float64
# mve_ia
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.05453181266785
# org    0.211177
# lm     0.492126
# knn    0.634107
# Name: mve_ia, dtype: float64
# nanalyst
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 77.75170707702637
# org    0.271339
# lm     0.166274
# knn    0.059913
# Name: nanalyst, dtype: float64
# nincr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 80.19157886505127
# org    1.255587
# lm     0.750925
# knn    0.287694
# Name: nincr, dtype: float64
# operprof
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 66.4328989982605
# org   -0.207765
# lm     0.331706
# knn    0.680860
# Name: operprof, dtype: float64
# roeq
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.3957040309906
# org    1.291804
# lm     0.861851
# knn    0.637856
# Name: roeq, dtype: float64
# roic
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 64.56649208068848
# org    0.305017
# lm     0.350513
# knn    0.685711
# Name: roic, dtype: float64
# rsup
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 72.76874995231628
# org    0.018382
# lm     0.510400
# knn    0.790301
# Name: rsup, dtype: float64
# salecash
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 70.69905519485474
# org    0.036211
# lm     0.262622
# knn    0.625703
# Name: salecash, dtype: float64
# saleinv
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 77.45250415802002
# org    0.398451
# lm     0.237455
# knn    0.605550
# Name: saleinv, dtype: float64
# salerec
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 71.31323218345642
# org   -0.462092
# lm     0.336175
# knn    0.640459
# Name: salerec, dtype: float64
# secured
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 95.79923701286316
# org   -0.624748
# lm     0.179800
# knn    0.704682
# Name: secured, dtype: float64
# securedind
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 97.87235689163208
# org   -1.076146
# lm     0.804862
# knn    0.385520
# Name: securedind, dtype: float64
# sfe
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 81.37182092666626
# org   -0.274036
# lm     0.439064
# knn    0.892196
# Name: sfe, dtype: float64
# sgr
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 74.74151396751404
# org   -0.925937
# lm     0.232397
# knn    0.492474
# Name: sgr, dtype: float64
# sin
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 106.84635496139526
# org   -0.101706
# lm     0.201474
# knn    0.196562
# Name: sin, dtype: float64
# sp
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 74.4309229850769
# org    0.284978
# lm     0.609206
# knn    0.695736
# Name: sp, dtype: float64
# std_dolvol
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 3184.0203421115875
# org   -0.482434
# lm    -0.331275
# knn   -0.431668
# Name: std_dolvol, dtype: float64
# quick
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 77.50831198692322
# org   -0.497387
# lm     0.456574
# knn    0.681581
# Name: quick, dtype: float64
# rd
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 100.41264295578003
# org   -0.553149
# lm     0.422017
# knn    0.275395
# Name: rd, dtype: float64
# rd_mve
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 89.7036759853363
# org    0.704631
# lm     0.429757
# knn    0.610452
# Name: rd_mve, dtype: float64
# rd_sale
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 91.02116799354553
# org    0.292223
# lm     0.100769
# knn    0.554216
# Name: rd_sale, dtype: float64
# realestate
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 93.55942010879517
# org    0.348281
# lm     0.104631
# knn    0.522927
# Name: realestate, dtype: float64
# retvol
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 92.53851413726807
# org   -1.561292
# lm     0.391233
# knn    0.349914
# Name: retvol, dtype: float64
# roaq
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 88.4779040813446
# org    0.736422
# lm     0.749570
# knn    0.782120
# Name: roaq, dtype: float64
# roavol
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 88.30242681503296
# org   -0.819710
# lm     0.152598
# knn    0.392932
# Name: roavol, dtype: float64
# std_turn
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 71.17102599143982
# org   -0.343767
# lm     0.163275
# knn    0.186258
# Name: std_turn, dtype: float64
# stdacc
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 83.56388401985168
# org   -0.200607
# lm     0.419748
# knn    0.454675
# Name: stdacc, dtype: float64
# stdcf
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 84.06089186668396
# org   -0.205430
# lm     0.504301
# knn    0.504304
# Name: stdcf, dtype: float64
# sue
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 73.48657488822937
# org    0.933625
# lm     0.724439
# knn    0.820318
# Name: sue, dtype: float64
# tang
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 84.1356258392334
# org   -0.344450
# lm     0.451708
# knn    0.652311
# Name: tang, dtype: float64
# tb
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 75.11546802520752
# org    0.753066
# lm     0.335131
# knn    0.510352
# Name: tb, dtype: float64
# turn
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 72.91880583763123
# org   -0.622817
# lm    -0.018056
# knn   -0.042867
# Name: turn, dtype: float64
# zerotrade
# -----------
# lm
# -----------
# -----------
# knn
# -----------
# -----------
# time = 69.37220597267151
# org    0.119575
# lm    -0.043141
# knn   -0.048971
# Name: zerotrade, dtype: float64

# %%
knn_sig_df.to_csv('/Users/raghuramkowdeed/Desktop/knn_sig_df_'+str(look_back)+ '.csv')

# %%
model_name = 'linear_regression'
train_model_arg = None
this_ret_sr = ret_sr[ (ret_sr.index>=knn_sig_df.index[0]) & (ret_sr.index<=knn_sig_df.index[1])]

all_lm_sig_sr, all_lm_model_vec = run_model( knn_sig_df, this_ret_sr, model_name, train_model_arg=None, 
                          pred_model_arg ={},look_back=look_back, sample_decay = 0.5, signs_vec=None)
all_lm_pnl_sr = pm.run_signal(all_lm_sig_sr, neu_sig=True)
all_lm_pnl_sr.cumsum().plot()
all_lm_shrp = all_lm_pnl_sr.mean()*sqrt(12)/all_lm_pnl_sr.std()
print( 'sharpe ratio = ' + str(all_lm_shrp) )
#pylab.title('lm_all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d5b89e853bc6> in <module>()
#       4
#       5 all_lm_sig_sr, all_lm_model_vec = run_model( knn_sig_df, this_ret_sr, model_name, train_model_arg=None,
# ----> 6                           pred_model_arg ={},look_back=look_back, sample_decay = sample_decay, signs_vec=None)
#       7 all_lm_pnl_sr = pm.run_signal(all_lm_sig_sr, neu_sig=True)
#       8 all_lm_pnl_sr.cumsum().plot()
#
# NameError: name 'sample_decay' is not defined
