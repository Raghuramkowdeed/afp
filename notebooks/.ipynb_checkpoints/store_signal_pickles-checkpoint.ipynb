# %%
import numpy as np
import pandas as pd
import os as os

# %%
os.chdir('../')

# %%
# %pylab inline
exec(open("./run_model.py").read())
exec(open("./get_signal_names.py").read())
exec(open("./portfolio_optimizer.py").read())

import datetime
from pylab import rcParams
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#sig_dir = '/Users/raghuramkowdeed/Desktop/afp_data/1000/ranked_rps_data/'
#fac_data_dir='/Users/raghuramkowdeed/Desktop/afp_data/1000/factor_exposure_data/'
#fac_ret_file = '/Users/raghuramkowdeed/Desktop/afp_data/1000/fac_ret_file.csv'

def store_sig_pickle(sig_type, size_tag,):
    #sig_type = 'rank'
    #rank
    #norm
    #size_tag = '500_3000'
    #0_3000
    #0_500
    #500_3000
    
    sig_dir =      '../afp_data/' + sig_type + '/' +  size_tag + '/rps_data/'
    fac_data_dir=  '../afp_data/' + sig_type + '/' +  size_tag + '/factor_exposure_data/'
    fac_ret_file = '../afp_data/' + sig_type + '/' +  size_tag + '/fac_ret_file.csv'
    sig_df = pd.DataFrame()
    sig_files = os.listdir(sig_dir)
    sig_files = np.sort(sig_files)



    for sig_file in sig_files :
        if '.csv' not in sig_file :
            continue
        print(sig_file)
        this_file = sig_dir + sig_file
        this_df = pd.read_csv(this_file, index_col = 'date')
        this_df.index = [ datetime.datetime.strptime(val, '%Y-%m-%d') for val in this_df.index]
        #this_df = this_df.sort_values(['mve'], ascending=False)
        #this_df = this_df.iloc[start_stock_ind:end_stock_ind,:]
        sig_df = sig_df.append(this_df)
    #data = sig_df.copy()
    
    
    file_name = 'sig_'+ sig_type + '_' + size_tag + '.pkl' 
    sig_df.to_pickle('../afp_pickle/'+file_name )
    
    begin_date = datetime.datetime.strptime('19900101', '%Y%m%d')
    end_date = datetime.datetime.strptime('20170101', '%Y%m%d')

    sig_df = sig_df[(sig_df.index>=begin_date) & (sig_df.index<end_date)]
    sig_df = sig_df.fillna(sig_df.mean())

    factor_names =  ['beta']
    sig_names = get_signal_names()
    ret_sr = sig_df['ret']
    sig_df = sig_df[sig_names]
    sig_df = sig_df.drop(factor_names, axis=1)
    sig_df = sig_df.drop(['idiovol'], axis=1)


    pm = PortfolioOptimizer(fac_data_dir=fac_data_dir,
                    fac_ret_file = fac_ret_file,
                    fac_cov_hl = 12.0,
                    fac_names = None
                   )


    pnl_df = pd.DataFrame()


    #these_signals = ['mve', 'bm', 'roic', 'agr', 'mom12m',]
    these_signals = sig_df.columns
    sig_signs = get_signal_signs()

    for sig_name in these_signals :
        print(sig_name)

        try :
            #t0 = time.time()
            #print(sig_name)
            this_sign = sig_signs[sig_name]
            this_sig_sr = sig_df[ [sig_name] ].copy()*np.sign(this_sign)

            #unmodified signal
            pnl_sr = pm.run_signal(this_sig_sr.iloc[:,0], neu_sig=True)
            pnl_df[sig_name] = pnl_sr
            print(pnl_sr.mean()*sqrt(12.0)/pnl_sr.std())


        except Exception as e :
            print(e)

    file_name = 'pnl_'+ sig_type + '_' + size_tag + '.pkl' 
    pnl_df.to_pickle('../afp_pickle/'+file_name )

    return 0

# %%
store_sig_pickle(sig_type='rank', size_tag='0_500')
# Out:
# 1980-01-31.csv
# 1980-02-29.csv
# 1980-03-31.csv
# 1980-04-30.csv
# 1980-05-30.csv
# 1980-06-30.csv
# 1980-07-31.csv
# 1980-08-29.csv
# 1980-09-30.csv
# 1980-10-31.csv
# 1980-11-28.csv
# 1980-12-31.csv
# 1981-01-30.csv
# 1981-02-27.csv
# 1981-03-31.csv
# 1981-04-30.csv
# 1981-05-29.csv
# 1981-06-30.csv
# 1981-07-31.csv
# 1981-08-31.csv
# 1981-09-30.csv
# 1981-10-30.csv
# 1981-11-30.csv
# 1981-12-31.csv
# 1982-01-29.csv
# 1982-02-26.csv
# 1982-03-31.csv
# 1982-04-30.csv
# 1982-05-28.csv
# 1982-06-30.csv
# 1982-07-30.csv
# 1982-08-31.csv
# 1982-09-30.csv
# 1982-10-29.csv
# 1982-11-30.csv
# 1982-12-31.csv
# 1983-01-31.csv
# 1983-02-28.csv
# 1983-03-31.csv
# 1983-04-29.csv
# 1983-05-31.csv
# 1983-06-30.csv
# 1983-07-29.csv
# 1983-08-31.csv
# 1983-09-30.csv
# 1983-10-31.csv
# 1983-11-30.csv
# 1983-12-30.csv
# 1984-01-31.csv
# 1984-02-29.csv
# 1984-03-30.csv
# 1984-04-30.csv
# 1984-05-31.csv
# 1984-06-29.csv
# 1984-07-31.csv
# 1984-08-31.csv
# 1984-09-28.csv
# 1984-10-31.csv
# 1984-11-30.csv
# 1984-12-31.csv
# 1985-01-31.csv
# 1985-02-28.csv
# 1985-03-29.csv
# 1985-04-30.csv
# 1985-05-31.csv
# 1985-06-28.csv
# 1985-07-31.csv
# 1985-08-30.csv
# 1985-09-30.csv
# 1985-10-31.csv
# 1985-11-29.csv
# 1985-12-31.csv
# 1986-01-31.csv
# 1986-02-28.csv
# 1986-03-31.csv
# 1986-04-30.csv
# 1986-05-30.csv
# 1986-06-30.csv
# 1986-07-31.csv
# 1986-08-29.csv
# 1986-09-30.csv
# 1986-10-31.csv
# 1986-11-28.csv
# 1986-12-31.csv
# 1987-01-30.csv
# 1987-02-27.csv
# 1987-03-31.csv
# 1987-04-30.csv
# 1987-05-29.csv
# 1987-06-30.csv
# 1987-07-31.csv
# 1987-08-31.csv
# 1987-09-30.csv
# 1987-10-30.csv
# 1987-11-30.csv
# 1987-12-31.csv
# 1988-01-29.csv
# 1988-02-29.csv
# 1988-03-31.csv
# 1988-04-29.csv
# 1988-05-31.csv
# 1988-06-30.csv
# 1988-07-29.csv
# 1988-08-31.csv
# 1988-09-30.csv
# 1988-10-31.csv
# 1988-11-30.csv
# 1988-12-30.csv
# 1989-01-31.csv
# 1989-02-28.csv
# 1989-03-31.csv
# 1989-04-28.csv
# 1989-05-31.csv
# 1989-06-30.csv
# 1989-07-31.csv
# 1989-08-31.csv
# 1989-09-29.csv
# 1989-10-31.csv
# 1989-11-30.csv
# 1989-12-29.csv
# 1990-01-31.csv
# 1990-02-28.csv
# 1990-03-30.csv
# 1990-04-30.csv
# 1990-05-31.csv
# 1990-06-29.csv
# 1990-07-31.csv
# 1990-08-31.csv
# 1990-09-28.csv
# 1990-10-31.csv
# 1990-11-30.csv
# 1990-12-31.csv
# 1991-01-31.csv
# 1991-02-28.csv
# 1991-03-28.csv
# 1991-04-30.csv
# 1991-05-31.csv
# 1991-06-28.csv
# 1991-07-31.csv
# 1991-08-30.csv
# 1991-09-30.csv
# 1991-10-31.csv
# 1991-11-29.csv
# 1991-12-31.csv
# 1992-01-31.csv
# 1992-02-28.csv
# 1992-03-31.csv
# 1992-04-30.csv
# 1992-05-29.csv
# 1992-06-30.csv
# 1992-07-31.csv
# 1992-08-31.csv
# 1992-09-30.csv
# 1992-10-30.csv
# 1992-11-30.csv
# 1992-12-31.csv
# 1993-01-29.csv
# 1993-02-26.csv
# 1993-03-31.csv
# 1993-04-30.csv
# 1993-05-28.csv
# 1993-06-30.csv
# 1993-07-30.csv
# 1993-08-31.csv
# 1993-09-30.csv
# 1993-10-29.csv
# 1993-11-30.csv
# 1993-12-31.csv
# 1994-01-31.csv
# 1994-02-28.csv
# 1994-03-31.csv
# 1994-04-29.csv
# 1994-05-31.csv
# 1994-06-30.csv
# 1994-07-29.csv
# 1994-08-31.csv
# 1994-09-30.csv
# 1994-10-31.csv
# 1994-11-30.csv
# 1994-12-30.csv
# 1995-01-31.csv
# 1995-02-28.csv
# 1995-03-31.csv
# 1995-04-28.csv
# 1995-05-31.csv
# 1995-06-30.csv
# 1995-07-31.csv
# 1995-08-31.csv
# 1995-09-29.csv
# 1995-10-31.csv
# 1995-11-30.csv
# 1995-12-29.csv
# 1996-01-31.csv
# 1996-02-29.csv
# 1996-03-29.csv
# 1996-04-30.csv
# 1996-05-31.csv
# 1996-06-28.csv
# 1996-07-31.csv
# 1996-08-30.csv
# 1996-09-30.csv
# 1996-10-31.csv
# 1996-11-29.csv
# 1996-12-31.csv
# 1997-01-31.csv
# 1997-02-28.csv
# 1997-03-31.csv
# 1997-04-30.csv
# 1997-05-30.csv
# 1997-06-30.csv
# 1997-07-31.csv
# 1997-08-29.csv
# 1997-09-30.csv
# 1997-10-31.csv
# 1997-11-28.csv
# 1997-12-31.csv
# 1998-01-30.csv
# 1998-02-27.csv
# 1998-03-31.csv
# 1998-04-30.csv
# 1998-05-29.csv
# 1998-06-30.csv
# 1998-07-31.csv
# 1998-08-31.csv
# 1998-09-30.csv
# 1998-10-30.csv
# 1998-11-30.csv
# 1998-12-31.csv
# 1999-01-29.csv
# 1999-02-26.csv
# 1999-03-31.csv
# 1999-04-30.csv
# 1999-05-28.csv
# 1999-06-30.csv
# 1999-07-30.csv
# 1999-08-31.csv
# 1999-09-30.csv
# 1999-10-29.csv
# 1999-11-30.csv
# 1999-12-31.csv
# 2000-01-31.csv
# 2000-02-29.csv
# 2000-03-31.csv
# 2000-04-28.csv
# 2000-05-31.csv
# 2000-06-30.csv
# 2000-07-31.csv
# 2000-08-31.csv
# 2000-09-29.csv
# 2000-10-31.csv
# 2000-11-30.csv
# 2000-12-29.csv
# 2001-01-31.csv
# 2001-02-28.csv
# 2001-03-30.csv
# 2001-04-30.csv
# 2001-05-31.csv
# 2001-06-29.csv
# 2001-07-31.csv
# 2001-08-31.csv
# 2001-09-28.csv
# 2001-10-31.csv
# 2001-11-30.csv
# 2001-12-31.csv
# 2002-01-31.csv
# 2002-02-28.csv
# 2002-03-28.csv
# 2002-04-30.csv
# 2002-05-31.csv
# 2002-06-28.csv
# 2002-07-31.csv
# 2002-08-30.csv
# 2002-09-30.csv
# 2002-10-31.csv
# 2002-11-29.csv
# 2002-12-31.csv
# 2003-01-31.csv
# 2003-02-28.csv
# 2003-03-31.csv
# 2003-04-30.csv
# 2003-05-30.csv
# 2003-06-30.csv
# 2003-07-31.csv
# 2003-08-29.csv
# 2003-09-30.csv
# 2003-10-31.csv
# 2003-11-28.csv
# 2003-12-31.csv
# 2004-01-30.csv
# 2004-02-27.csv
# 2004-03-31.csv
# 2004-04-30.csv
# 2004-05-28.csv
# 2004-06-30.csv
# 2004-07-30.csv
# 2004-08-31.csv
# 2004-09-30.csv
# 2004-10-29.csv
# 2004-11-30.csv
# 2004-12-31.csv
# 2005-01-31.csv
# 2005-02-28.csv
# 2005-03-31.csv
# 2005-04-29.csv
# 2005-05-31.csv
# 2005-06-30.csv
# 2005-07-29.csv
# 2005-08-31.csv
# 2005-09-30.csv
# 2005-10-31.csv
# 2005-11-30.csv
# 2005-12-30.csv
# 2006-01-31.csv
# 2006-02-28.csv
# 2006-03-31.csv
# 2006-04-28.csv
# 2006-05-31.csv
# 2006-06-30.csv
# 2006-07-31.csv
# 2006-08-31.csv
# 2006-09-29.csv
# 2006-10-31.csv
# 2006-11-30.csv
# 2006-12-29.csv
# 2007-01-31.csv
# 2007-02-28.csv
# 2007-03-30.csv
# 2007-04-30.csv
# 2007-05-31.csv
# 2007-06-29.csv
# 2007-07-31.csv
# 2007-08-31.csv
# 2007-09-28.csv
# 2007-10-31.csv
# 2007-11-30.csv
# 2007-12-31.csv
# 2008-01-31.csv
# 2008-02-29.csv
# 2008-03-31.csv
# 2008-04-30.csv
# 2008-05-30.csv
# 2008-06-30.csv
# 2008-07-31.csv
# 2008-08-29.csv
# 2008-09-30.csv
# 2008-10-31.csv
# 2008-11-28.csv
# 2008-12-31.csv
# 2009-01-30.csv
# 2009-02-27.csv
# 2009-03-31.csv
# 2009-04-30.csv
# 2009-05-29.csv
# 2009-06-30.csv
# 2009-07-31.csv
# 2009-08-31.csv
# 2009-09-30.csv
# 2009-10-30.csv
# 2009-11-30.csv
# 2009-12-31.csv
# 2010-01-29.csv
# 2010-02-26.csv
# 2010-03-31.csv
# 2010-04-30.csv
# 2010-05-28.csv
# 2010-06-30.csv
# 2010-07-30.csv
# 2010-08-31.csv
# 2010-09-30.csv
# 2010-10-29.csv
# 2010-11-30.csv
# 2010-12-31.csv
# 2011-01-31.csv
# 2011-02-28.csv
# 2011-03-31.csv
# 2011-04-29.csv
# 2011-05-31.csv
# 2011-06-30.csv
# 2011-07-29.csv
# 2011-08-31.csv
# 2011-09-30.csv
# 2011-10-31.csv
# 2011-11-30.csv
# 2011-12-30.csv
# 2012-01-31.csv
# 2012-02-29.csv
# 2012-03-30.csv
# 2012-04-30.csv
# 2012-05-31.csv
# 2012-06-29.csv
# 2012-07-31.csv
# 2012-08-31.csv
# 2012-09-28.csv
# 2012-10-31.csv
# 2012-11-30.csv
# 2012-12-31.csv
# 2013-01-31.csv
# 2013-02-28.csv
# 2013-03-28.csv
# 2013-04-30.csv
# 2013-05-31.csv
# 2013-06-28.csv
# 2013-07-31.csv
# 2013-08-30.csv
# 2013-09-30.csv
# 2013-10-31.csv
# 2013-11-29.csv
# 2013-12-31.csv
# 2014-01-31.csv
# 2014-02-28.csv
# 2014-03-31.csv
# 2014-04-30.csv
# 2014-05-30.csv
# 2014-06-30.csv
# 2014-07-31.csv
# 2014-08-29.csv
# 2014-09-30.csv
# 2014-10-31.csv
# 2014-11-28.csv
# 2014-12-31.csv
# 2015-01-30.csv
# 2015-02-27.csv
# 2015-03-31.csv
# 2015-04-30.csv
# 2015-05-29.csv
# 2015-06-30.csv
# 2015-07-31.csv
# 2015-08-31.csv
# 2015-09-30.csv
# 2015-10-30.csv
# 2015-11-30.csv
# 2015-12-31.csv
# 2016-01-29.csv
# 2016-02-29.csv
# 2016-03-31.csv
# 2016-04-29.csv
# 2016-05-31.csv
# 2016-06-30.csv
# 2016-07-29.csv
# 2016-08-31.csv
# 2016-09-30.csv
# 2016-10-31.csv
# 2016-11-30.csv
# 2016-12-30.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-500c16a52747> in <module>()
# ----> 1 store_sig_pickle(sig_type='rank', size_tag='0_500')
#
# <ipython-input-8-89c7ee46f0af> in store_sig_pickle(sig_type, size_tag)
#      35
#      36     file_name = 'sig_'+ sig_type + '_' + size_tag + '.pkl'
# ---> 37     sig_df.to_pickle('../../afp_pickle/'+file_name )
#      38
#      39     begin_date = datetime.datetime.strptime('19900101', '%Y%m%d')
#
# /Users/raghuramkowdeed/Applications/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in to_pickle(self, path)
#    1175         """
#    1176         from pandas.io.pickle import to_pickle
# -> 1177         return to_pickle(self, path)
#    1178
#    1179     def to_clipboard(self, excel=None, sep=None, **kwargs):
#
# /Users/raghuramkowdeed/Applications/anaconda/lib/python3.5/site-packages/pandas/io/pickle.py in to_pickle(obj, path)
#      17         File path
#      18     """
# ---> 19     with open(path, 'wb') as f:
#      20         pkl.dump(obj, f, protocol=pkl.HIGHEST_PROTOCOL)
#      21
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../afp_pickle/sig_rank_0_500.pkl'

# %%
store_sig_pickle(sig_type='rank', size_tag='500_3000')

# %%
store_sig_pickle(sig_type='rank', size_tag='0_3000')

# %%
'../'
